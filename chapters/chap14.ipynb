# %% [markdown]
# <a href="https://colab.research.google.com/github/gabgab132ggmm/think-python/blob/main/chapters/chap14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install colorama

# %%
from colorama import init, Fore, Style
print(Fore.GREEN + """print('                           .,:7I::,.')
print('                           :cTKKWWWWUOWm')
print('                       .2ZWWWWWWWWWWWWAI        ,,..')
print('                    .:mAWWWWW: 7..   .        2W2')
print('                    7WWWAWG                  ,WWWBEAEAmGmUoII;..')
print('                    NWEmAG                .cWWWEEBWBANEWWWWWWWWWWO.')
print('                    pWBANp7;;.        .7SWWWWAKAmDDDmmOUOOSGGKmOSWWm:')
print('      7Gm        .:.mWKmKmAWWWWWWWWWWWWWWWWApSGNpSOU2DKD2U222OKAD2DEWWt')
print('      ,2B       ;2I,IWADKBAAEBEBBEEEWBEANKGpSDmKpSODDZSAD22ZZZCOKG2UmWWWI')
print('      .,IU:..;CKBW7.;GAApKpKAAEEAANNAAANKKKKKNNKGGDODOUKK222CCTCTmKSK0TEWW')
print('    ,.17;oGGpmmDGD:,.IWESUpKKKNBBEEBWWWWWWAKKAEKAANANKpKKGGGSmmmpUKWo    SW.')
print('   ,,.o7I000ZTTCDO;.:.IWBmmNGGGmEWWWZZSKEWWWBAWWWWWWWBAABBWWNO22ONWWW     ,A')
print('  .,,,tIco00T0ZUmBO.,::UKWKNNW7  ;0T       7AWK7,..:tKWEWWD.      .UW:     ;')
print('  ,::,c0IctCTOKNpZO2:.,,0BEEEKN             Zp        7WW:          WW')
print(' .;7;;;ZottZKS;    GN;.,II12BWW7 WWK.       .          AW           ;W')
print('..;oot7722DS,       SAI7;.;IItZWWWWWW;.                WT           I.')
print(' .;12C2CcWW          oWp:.;:t1;;77SKWWWZG.:.           0')
print('  ;;TUT  .G;          ;0,;;IWWWp1,   ;ICUSWpo2Ao,.;')
print('  ;;;G:    .         .c0:7KWK72WWWWASZIt117IZU2OmmANSKK7,7.')
print('  .1tt2              ,KcUWW.      :12DKKEABWWWWWWWWWWWWWWWWKmO,.')
print('   Im,W1              7KDAU;0.                ...:;7tZOKNWWWWWWWWO2;')
print('   17:;W:              ,;T2DWW:                            .:7ZGEWWWAA;.')
print('   .W   0;                  cWW7                                  ,I2EWWpI,')
print('    :S.                      .IEBC1.                                  .1SNWG:')
print('      ;                        7Wt                                        7OKG')
print('                                KWWc.                                       :SW')
print('                                 OSc,                                         KS')
print('                                                                              .E')
print('                                                                              ,E')
                                                                              """)
# Out:
# print('                           .,:7I::,.')
# print('                           :cTKKWWWWUOWm')
# print('                       .2ZWWWWWWWWWWWWAI        ,,..')
# print('                    .:mAWWWWW: 7..   .        2W2')
# print('                    7WWWAWG                  ,WWWBEAEAmGmUoII;..')
# print('                    NWEmAG                .cWWWEEBWBANEWWWWWWWWWWO.')
# print('                    pWBANp7;;.        .7SWWWWAKAmDDDmmOUOOSGGKmOSWWm:')
# print('      7Gm        .:.mWKmKmAWWWWWWWWWWWWWWWWApSGNpSOU2DKD2U222OKAD2DEWWt')
# print('      ,2B       ;2I,IWADKBAAEBEBBEEEWBEANKGpSDmKpSODDZSAD22ZZZCOKG2UmWWWI')
# print('      .,IU:..;CKBW7.;GAApKpKAAEEAANNAAANKKKKKNNKGGDODOUKK222CCTCTmKSK0TEWW')
# print('    ,.17;oGGpmmDGD:,.IWESUpKKKNBBEEBWWWWWWAKKAEKAANANKpKKGGGSmmmpUKWo    SW.')
# print('   ,,.o7I000ZTTCDO;.:.IWBmmNGGGmEWWWZZSKEWWWBAWWWWWWWBAABBWWNO22ONWWW     ,A')
# print('  .,,,tIco00T0ZUmBO.,::UKWKNNW7  ;0T       7AWK7,..:tKWEWWD.      .UW:     ;')
# ...
